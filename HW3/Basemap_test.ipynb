# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1,figsize=(12,12))

map = Basemap()
map.drawcoastlines()
plt.show()
plt.savefig('coastlines_test.png')

# %%
fig2, ax = plt.subplots(1,1,figsize=(12,12))
map_ortho = Basemap(projection='ortho', lat_0 = 11, lon_0 = 0)
map_ortho.drawmapboundary(fill_color = 'aqua')
map_ortho.fillcontinents(color='lightcoral',lake_color='aqua')
map_ortho.drawcoastlines()
plt.show()
